# %% [markdown]
# <a href="https://colab.research.google.com/github/sanyam0712/Big-Data-MCA-/blob/main/2ndapril(assignment6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd


url = 'https://raw.githubusercontent.com/AnjulaMehto/MCA/main/company_sales_data.csv'
data = pd.read_csv(url)


data
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
data.columns
# Out:
# Index(['month_number', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
#        'shampoo', 'moisturizer', 'total_units', 'total_profit'],
#       dtype='object')

# %%
sns.lineplot(x='month_number',y ='total_profit',data=data)
# Out:
# <Axes: xlabel='month_number', ylabel='total_profit'>

# %%
products = ['facecream', 'facewash', 'toothpaste', 'bathingsoap',
       'shampoo', 'moisturizer']
for i in products:
  sns.lineplot(x=data['month_number'],y = data[i],label=i)

# %%
for i in products:
  sns.barplot(x=data['month_number'],y = data[i],label=i)

# %%
import plotly.express as px


df = px.data.iris()
fig = px.scatter(df,x='sepal_width',y='sepal_length')
fig.show()


fig2 = px.bar(df,x='sepal_width',y='sepal_length')
fig2.show()


fig3 = px.histogram(df,x='sepal_width',y='sepal_length')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
