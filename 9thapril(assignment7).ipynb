# %% [markdown]
# <a href="https://colab.research.google.com/github/sanyam0712/Big-Data-MCA-/blob/main/9thapril(assignment7).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd


data = pd.read_csv('/content/Salary_Data.csv')
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values


from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


data
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)


regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regressor.predict([[11]])
# Out:
# array([129362.14216718])

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test,regressor.predict(x_test),color='red')
plt.plot(x_test,y_test,color='blue')

# %%
y_pred = regressor.predict(x_test)
from sklearn.metrics import r2_score
R2score = r2_score(y_test,y_pred)
R2score
# Out:
# 0.9452046804782148

# %%
x = [4,5,10,4,3,11,14,6,10,12]
#  1 * 10

y = [21,19,24,17,16,25,24,22,21,21]

sum_x = sum(x)
sum_y = sum(y)

xy = 0
for i in range(len(x)):
  xy += x[i] * y[i]

x_2 = 0
for i in range(len(x)):
  x_2 += x[i] * x[i]


# b = (sum(x,y) - sum(x) * sum(y) / sum(x^2) - (sum(x)**2))

b = (xy - (sum_x * sum_y))/(x_2 - (sum_x**2))
# y = bx + a
a = (sum_y/len(y)) - b * (sum_x/len(x))


def mylinearmodel(x):
  return (b*x + a)


x_new = [5,37,8,12,3,11,10]
New_X =[6,7,8,3,1,9,16,5,9,9,6,8,14,8,5,14,18,10,14,15]
New_Y = [22,18,25,15,14,26,22 ,20 ,24 ,19 ,27 ,25 ,27 ,22 ,21 ,28 ,29 ,25 ,25 ,27]
y_pred = []
for i in New_X:
  ans = mylinearmodel(i)
  y_pred.append(ans)


plt.scatter(New_X,New_Y,color='red')
plt.plot(New_X,y_pred)
